# %% [markdown]
# ## PySCF with OpenFermion
#
# Graphene nanoribon calculated with PySCF with OpenFermion.
#
#
# Based on the example from [https://github.com/quantumlib/OpenFermion-PySCF](https://github.com/quantumlib/OpenFermion-PySCF)

# %%
from ase.visualize import view
from ase.build import graphene_nanoribbon
gnr1 = graphene_nanoribbon(2, 2, type='armchair', saturated=True, vacuum=3.5)
#gnr1 = graphene_nanoribbon(3, 4, type='zigzag', saturated=True, vacuum=3.5)
view(gnr1, viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="6.90 3.50 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="8.13 3.50 0.71">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="8.13 3.50 2.13">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.90 3.50 2.84">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.90 3.50 4.26">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="8.13 3.50 4.97">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="8.13 3.50 6.39">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.90 3.50 7.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.44 3.50 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.67 3.50 0.71">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.67 3.50 2.13">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.44 3.50 2.84">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.44 3.50 4.26">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.67 3.50 4.97">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.67 3.50 6.39">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.44 3.50 7.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.50 3.50 0.55">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.50 3.50 2.29">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.50 3.50 4.80">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.50 3.50 6.55">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.08 3.50 0.16">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.08 3.50 2.67">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.08 3.50 4.42">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.08 3.50 6.93">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#    </Scene>
#
#   </X3D>
#
#  </body>
#
# </html>

# %%
from ase.io.xyz import write_xyz
import io

f = io.StringIO()
gnr1.write(f,format='xyz')
graphene_geometry=[(a.split()[0],(float(a.split()[1]),float(a.split()[2]),float(a.split()[3]))) for a in f.getvalue().split('\n')[2:-1]]

# %%
from openfermion.chem import MolecularData
from openfermionpyscf import run_pyscf

# Set molecule parameters.
basis = 'sto-3g'
multiplicity = 1

# Set calculation parameters.
run_scf = 1
run_mp2 = 0 
run_cisd = 0
run_ccsd = 0
run_fci = 0

molecule = MolecularData(
    graphene_geometry, basis, multiplicity,
    description="graphene nanoribbon")

# Run pyscf.
molecule = run_pyscf(molecule,
                     run_scf=run_scf,
                     run_mp2=run_mp2,
                     run_cisd=run_cisd,
                     run_ccsd=run_ccsd,
                     run_fci=run_fci)


print(f'Hartree-Fock energy of {molecule.hf_energy} Hartree.')
print(f'Nuclear repulsion energy between protons is {molecule.nuclear_repulsion} Hartree.')
for orbital in range(molecule.n_orbitals):
    print(f'Spatial orbital {orbital} has energy of {molecule.orbital_energies[orbital]} Hartree.')
# Out:
# Hartree-Fock energy of -602.3486206423569 Hartree.
# Spatial orbital 44 has energy of -0.3901948114631012 Hartree.
# Spatial orbital 45 has energy of -0.3502906023307574 Hartree.
# Spatial orbital 46 has energy of -0.32752960245691765 Hartree.
# Spatial orbital 47 has energy of -0.24872981114834142 Hartree.
# Spatial orbital 48 has energy of -0.24634494620710595 Hartree.
# Spatial orbital 49 has energy of -0.24103384194307684 Hartree.
# Spatial orbital 50 has energy of -0.24017104869768224 Hartree.
# Spatial orbital 51 has energy of -0.12523707744570356 Hartree.
# Spatial orbital 52 has energy of -0.048014990632335455 Hartree.
# Spatial orbital 53 has energy of 0.11417298424705098 Hartree.
# Spatial orbital 54 has energy of 0.15553174204700732 Hartree.
# Spatial orbital 55 has energy of 0.22636958443215816 Hartree.
# Spatial orbital 56 has energy of 0.24010165902376457 Hartree.
# Spatial orbital 57 has energy of 0.31983920109218145 Hartree.
# Spatial orbital 58 has energy of 0.3525728899997598 Hartree.
# Spatial orbital 59 has energy of 0.3779156643799326 Hartree.
# Spatial orbital 60 has energy of 0.4889684881044222 Hartree.
# Spatial orbital 61 has energy of 0.5384584474144377 Hartree.
# Spatial orbital 62 has energy of 0.5589792847807281 Hartree.
# Spatial orbital 63 has energy of 0.5877999015234385 Hartree.
# Spatial orbital 64 has energy of 0.5975350794171814 Hartree.
# Spatial orbital 65 has energy of 0.6210978239867206 Hartree.
# Spatial orbital 66 has energy of 0.6279904147838405 Hartree.
# Spatial orbital 67 has energy of 0.6616652212015472 Hartree.
# Spatial orbital 68 has energy of 0.6631554030691604 Hartree.
# Spatial orbital 69 has energy of 0.6693052612349516 Hartree.
# Spatial orbital 70 has energy of 0.6793240351065544 Hartree.
# Spatial orbital 71 has energy of 0.7411084498423022 Hartree.
# Spatial orbital 72 has energy of 0.7461428949629583 Hartree.
# Spatial orbital 73 has energy of 0.7563806758843912 Hartree.
# Spatial orbital 74 has energy of 0.7869492599897135 Hartree.
# Spatial orbital 75 has energy of 0.7972281576962632 Hartree.
# Spatial orbital 76 has energy of 0.8210246541683434 Hartree.
# Spatial orbital 77 has energy of 0.8334410762463773 Hartree.
# Spatial orbital 78 has energy of 0.8701318655392336 Hartree.
# Spatial orbital 79 has energy of 0.8952445710644154 Hartree.
# Spatial orbital 80 has energy of 0.9078975111111701 Hartree.
# Spatial orbital 81 has energy of 0.9461218396771568 Hartree.
# Spatial orbital 82 has energy of 0.9668395250853631 Hartree.
# Spatial orbital 83 has energy of 0.9842900161633308 Hartree.
# Spatial orbital 84 has energy of 1.0510754178038886 Hartree.
# Spatial orbital 85 has energy of 1.0554651548720666 Hartree.
# Spatial orbital 86 has energy of 1.128228814085267 Hartree.
# Spatial orbital 87 has energy of 1.1517992880852057 Hartree.
