# %% [markdown]
# ## PySCF with OpenFermion
#
# Graphene nanoribon calculated with PySCF with OpenFermion.
#
#
# Based on the example from [https://github.com/quantumlib/OpenFermion-PySCF](https://github.com/quantumlib/OpenFermion-PySCF)

# %%
from ase.visualize import view
from ase.build import graphene_nanoribbon
gnr1 = graphene_nanoribbon(2, 2, type='armchair', saturated=True, vacuum=3.5)
#gnr1 = graphene_nanoribbon(3, 4, type='zigzag', saturated=True, vacuum=3.5)
view(gnr1, viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="6.90 3.50 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="8.13 3.50 0.71">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="8.13 3.50 2.13">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.90 3.50 2.84">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.90 3.50 4.26">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="8.13 3.50 4.97">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="8.13 3.50 6.39">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.90 3.50 7.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.44 3.50 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.67 3.50 0.71">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.67 3.50 2.13">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.44 3.50 2.84">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.44 3.50 4.26">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.67 3.50 4.97">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.67 3.50 6.39">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.44 3.50 7.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.50 3.50 0.55">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.50 3.50 2.29">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.50 3.50 4.80">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.50 3.50 6.55">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.08 3.50 0.16">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.08 3.50 2.67">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.08 3.50 4.42">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.08 3.50 6.93">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#    </Scene>
#
#   </X3D>
#
#  </body>
#
# </html>

# %%
from ase.io.xyz import write_xyz
import io

f = io.StringIO()
gnr1.write(f,format='xyz')
graphene_geometry=[(a.split()[0],(float(a.split()[1]),float(a.split()[2]),float(a.split()[3]))) for a in f.getvalue().split('\n')[2:-1]]

# %%
from openfermion.chem import MolecularData
from openfermionpyscf import run_pyscf

# Set molecule parameters.
basis = 'sto-3g'
multiplicity = 1

# Set calculation parameters.
run_scf = 1
run_mp2 = 0 
run_cisd = 0
run_ccsd = 0
run_fci = 0

molecule = MolecularData(
    graphene_geometry, basis, multiplicity,
    description="graphene nanoribbon")

# Run pyscf.
molecule = run_pyscf(molecule,
                     run_scf=run_scf,
                     run_mp2=run_mp2,
                     run_cisd=run_cisd,
                     run_ccsd=run_ccsd,
                     run_fci=run_fci)


print(f'Hartree-Fock energy of {molecule.hf_energy} Hartree.')
print(f'Nuclear repulsion energy between protons is {molecule.nuclear_repulsion} Hartree.')
for orbital in range(molecule.n_orbitals):
    print(f'Spatial orbital {orbital} has energy of {molecule.orbital_energies[orbital]} Hartree.')
# Out:
# Hartree-Fock energy of -602.3486206423942 Hartree.
# Nuclear repulsion energy between protons is 904.5048088363402 Hartree.
# Spatial orbital 0 has energy of -11.082713221707202 Hartree.
# Spatial orbital 1 has energy of -11.08264421655579 Hartree.
# Spatial orbital 2 has energy of -11.079132575714008 Hartree.
# Spatial orbital 3 has energy of -11.079075954622358 Hartree.
# Spatial orbital 4 has energy of -11.065437976995147 Hartree.
# Spatial orbital 5 has energy of -11.065376264189863 Hartree.
# Spatial orbital 6 has energy of -11.056632566193548 Hartree.
# Spatial orbital 7 has energy of -11.056403879164899 Hartree.
# Spatial orbital 8 has energy of -11.051403374133328 Hartree.
# Spatial orbital 9 has energy of -11.051403062092273 Hartree.
# Spatial orbital 10 has energy of -11.044772964328985 Hartree.
# Spatial orbital 11 has energy of -11.044769053309832 Hartree.
# Spatial orbital 12 has energy of -11.028332881836395 Hartree.
# Spatial orbital 13 has energy of -11.028332657499352 Hartree.
# Spatial orbital 14 has energy of -10.954726230492216 Hartree.
# Spatial orbital 15 has energy of -10.95472598390098 Hartree.
# Spatial orbital 16 has energy of -1.1549264014008411 Hartree.
# Spatial orbital 17 has energy of -1.1035968750264618 Hartree.
# Spatial orbital 18 has energy of -1.0520703838140104 Hartree.
# Spatial orbital 19 has energy of -1.020524162629261 Hartree.
# Spatial orbital 20 has energy of -1.0036447730105724 Hartree.
# Spatial orbital 21 has energy of -0.9422237431544948 Hartree.
# Spatial orbital 22 has energy of -0.9346470236530547 Hartree.
# Spatial orbital 23 has energy of -0.8594436954166448 Hartree.
# Spatial orbital 24 has energy of -0.8322238972531928 Hartree.
# Spatial orbital 25 has energy of -0.8181927347668606 Hartree.
# Spatial orbital 26 has energy of -0.7775713661052814 Hartree.
# Spatial orbital 27 has energy of -0.7493665457040274 Hartree.
# Spatial orbital 28 has energy of -0.6879879045728934 Hartree.
# Spatial orbital 29 has energy of -0.6697676309912868 Hartree.
# Spatial orbital 30 has energy of -0.6692545214178621 Hartree.
# Spatial orbital 31 has energy of -0.6331039052261163 Hartree.
# Spatial orbital 32 has energy of -0.5934645068081957 Hartree.
# Spatial orbital 33 has energy of -0.5797555829701342 Hartree.
# Spatial orbital 34 has energy of -0.5646461228663152 Hartree.
# Spatial orbital 35 has energy of -0.543996689724573 Hartree.
# Spatial orbital 36 has energy of -0.535349801304369 Hartree.
# Spatial orbital 37 has energy of -0.5274757160683924 Hartree.
# Spatial orbital 38 has energy of -0.5262839699645573 Hartree.
# Spatial orbital 39 has energy of -0.5177789562885827 Hartree.
# Spatial orbital 40 has energy of -0.466955553842838 Hartree.
# Spatial orbital 41 has energy of -0.46001482122366266 Hartree.
# Spatial orbital 42 has energy of -0.45573961791001466 Hartree.
# Spatial orbital 43 has energy of -0.41848344104211405 Hartree.
# Spatial orbital 44 has energy of -0.39019509944680086 Hartree.
# Spatial orbital 45 has energy of -0.3502902717042716 Hartree.
# Spatial orbital 46 has energy of -0.327529315473174 Hartree.
# Spatial orbital 47 has energy of -0.24872949582456752 Hartree.
# Spatial orbital 48 has energy of -0.2463454180978093 Hartree.
# Spatial orbital 49 has energy of -0.24103390290134952 Hartree.
# Spatial orbital 50 has energy of -0.2401710814100901 Hartree.
# Spatial orbital 51 has energy of -0.12523712730964695 Hartree.
# Spatial orbital 52 has energy of -0.04801503794364259 Hartree.
# Spatial orbital 53 has energy of 0.11417259876834263 Hartree.
# Spatial orbital 54 has energy of 0.15553211445840306 Hartree.
# Spatial orbital 55 has energy of 0.22636934227641312 Hartree.
# Spatial orbital 56 has energy of 0.2401014709298008 Hartree.
# Spatial orbital 57 has energy of 0.3198394294024839 Hartree.
# Spatial orbital 58 has energy of 0.3525726971915035 Hartree.
# Spatial orbital 59 has energy of 0.3779155555241537 Hartree.
# Spatial orbital 60 has energy of 0.488968466390025 Hartree.
# Spatial orbital 61 has energy of 0.5384587350241953 Hartree.
# Spatial orbital 62 has energy of 0.5589792177840265 Hartree.
# Spatial orbital 63 has energy of 0.5877996594208079 Hartree.
# Spatial orbital 64 has energy of 0.597534828784114 Hartree.
# Spatial orbital 65 has energy of 0.6210984378604277 Hartree.
# Spatial orbital 66 has energy of 0.6279906238918107 Hartree.
# Spatial orbital 67 has energy of 0.661664785090048 Hartree.
# Spatial orbital 68 has energy of 0.663155374569751 Hartree.
# Spatial orbital 69 has energy of 0.669305075605523 Hartree.
# Spatial orbital 70 has energy of 0.6793240174957399 Hartree.
# Spatial orbital 71 has energy of 0.7411083726602733 Hartree.
# Spatial orbital 72 has energy of 0.7461431197512346 Hartree.
# Spatial orbital 73 has energy of 0.7563806516886885 Hartree.
# Spatial orbital 74 has energy of 0.7869492068444782 Hartree.
# Spatial orbital 75 has energy of 0.797228314551134 Hartree.
# Spatial orbital 76 has energy of 0.8210244524746454 Hartree.
# Spatial orbital 77 has energy of 0.8334411507313009 Hartree.
# Spatial orbital 78 has energy of 0.8701318449462543 Hartree.
# Spatial orbital 79 has energy of 0.8952446791423732 Hartree.
# Spatial orbital 80 has energy of 0.9078970131163994 Hartree.
# Spatial orbital 81 has energy of 0.9461220401853516 Hartree.
# Spatial orbital 82 has energy of 0.9668394706879364 Hartree.
# Spatial orbital 83 has energy of 0.9842899816634704 Hartree.
# Spatial orbital 84 has energy of 1.0510754078617626 Hartree.
# Spatial orbital 85 has energy of 1.0554651335252416 Hartree.
# Spatial orbital 86 has energy of 1.1282288156736122 Hartree.
# Spatial orbital 87 has energy of 1.1517991500048776 Hartree.
